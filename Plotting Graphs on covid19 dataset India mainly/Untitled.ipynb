# %% [markdown]
# # Covid19 data of India till 20-May-2020

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data_india= pd.read_csv("state3_data.csv")

# %%
data_india
# Out:
#          State/UT Confirmed  Active Recovered Deceased
# 0  Madhya Pradesh     5,543   2,652     2,631      260
# 1      Tamil Nadu    12,448   7,468     4,895       85
# 2         Gujarat    12,141   6,379     5,043      719
# 3   Uttar Pradesh     4,926   1,885     2,918      123
# 4     West Bengal     2,961   1,637     1,074      250
# 5  Andhra Pradesh     2,560     843     1,664       53
# 6           Delhi    11,088   5,720     5,192      176
# 7       Rajasthan     5,952   2,436     3,373      143
# 8     Maharashtra    37,136  26,172     9,639    1,325
# 9          Punjab     2,002     322     1,642       38

# %%
x=data_india["State/UT"]
y=data_india["Confirmed"]

# %%
plt.figure(figsize=(36,25))

plt.bar(x,y)

plt.show()
